# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %%
read_data=np.load(r'F:\pytong\utaeV2\PASTIS_SMOLL\ANNOTATIONS\TARGET_10005.npy')
read_img=np.load(r'F:\pytong\utaeV2\PASTIS_SMOLL\DATA_S2\S2_10005.npy')


# min=np.min(read_data)
# max=np.max(read_data)

# # scaled_image = np.round((read_data - 0) * (255 / (2147483647 - 0)))

# print(min , max)

# read_img.dtype
img_t=read_data[0,:,:]
plt.imshow(img_t)
plt.show()



# Znajdź unikatowe kolory w obrazie
unique_colors = np.unique(img_t)

# %% [markdown]
# # Znajdź unikalne etykiety
# unique_labels = np.unique(read_data)
#
# # Wygeneruj losowe kolory o wartościach 0-255
# random_colors = np.random.randint(0, 255 + 1, (len(unique_labels), 3))
#
# # Przeskaluj wartości kolorów do zakresu 0-1
# random_colors_normalized = random_colors / 255.0
#
# # Utwórz mapę kolorów na podstawie wygenerowanych kolorów
# cmap = ListedColormap(random_colors_normalized)
#
# # Wygeneruj obraz kolorowy na podstawie etykiet
# colored_image = cmap(read_data)

# %%
unique_labels = np.unique(read_data)

# Wybierz mapę kolorów z matplotlib (np. 'viridis', 'jet', 'coolwarm', 'rainbow', itp.)
cmap_name = 'viridis'

# Wygeneruj mapę kolorów na podstawie etykiet i wybranej mapy kolorów
cmap = plt.get_cmap(cmap_name, len(unique_labels))

# Wygeneruj obraz kolorowy na podstawie etykiet i mapy kolorów
colored_image = cmap(read_data)

# %%
plt.imshow(colored_image)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11860\2750802767.py in <module>
# ----> 1 plt.imshow(colored_image)
#       2 plt.show()
#       3
#
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     457                 "parameter will become keyword-only %(removal)s.",
#     458                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459         return func(*args, **kwargs)
#     460
#     461     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# c:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2650         interpolation_stage=None, filternorm=True, filterrad=4.0,
# ...

# %%
read_single_img=read_img[2,0:3,:,:]
norm = cv2.normalize(read_single_img, None, 0, 255, cv2.NORM_MINMAX, dtype=cv2.CV_8U)
transposed_img=np.transpose(norm,(1,2,0))
reshaped_img=np.reshape(transposed_img,(128,128,3))


# Wyświetlenie obrazu za pomocą OpenCV
cv2.imshow('Obraz', reshaped_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

reshaped_img_RGB = cv2.cvtColor(reshaped_img, cv2.COLOR_BGR2RGB)

plt.imshow(reshaped_img_RGB)
